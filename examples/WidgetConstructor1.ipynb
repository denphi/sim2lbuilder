# %%
from sim2lbuilder import WidgetConstructor

# %%
# %reload_ext yamlmagic
# %matplotlib inline

# %%
# %%yaml
# inputs:
#     float1:
#         type : TextField
#         module : uidlcomponents
#         value : 2.0
#         help : This is a textfield
#         description : Scale
#     float2:
#         type : TextField
#         module : uidlcomponents
#         value : 1.5
#         help : This is a extra textfield
#         description : Angle
#     button1:
#         type : Button
#         click : ClickFun
#         description : Run ClickButton
#     button2:
#         type : Button
#         click : ResetFun
#         description : Reset
# outputs:
#     out1 :
#         type: FigureWidget
#         module: plotly.graph_objects
#
# layout:
#     type: VBox
#     border: 1px solid
#     children:
#         float1:
#         float2:
#         button1:
#         out1:
#         button2:
# Out:
# {'inputs': {'float1': {'type': 'TextField',
#    'module': 'uidlcomponents',
#    'value': 2.0,
#    'help': 'This is a textfield',
#    'description': 'Scale'},
#   'float2': {'type': 'TextField',
#    'module': 'uidlcomponents',
#    'value': 1.5,
#    'help': 'This is a extra textfield',
#    'description': 'Angle'},
#   'button1': {'type': 'Button',
#    'click': 'ClickFun',
#    'description': 'Run ClickButton'},
#   'button2': {'type': 'Button', 'click': 'ResetFun', 'description': 'Reset'}},
#  'outputs': {'out1': {'type': 'FigureWidget',
#    'module': 'plotly.graph_objects'}},
#  'layout': {'type': 'VBox',
#   'border': '1px solid',
#   'children': {'float1': None,
#    'float2': None,
#    'button1': None,
#    'out1': None,
#    'button2': None}}}

# %%
schema = _

# %%
def ResetFun(widget, *kargs):
    out1 = widget.outputs["out1"]
    out1.data = []
    
def ClickFun(widget, *kargs):
    import numpy as np
    import plotly.graph_objects as go
    n1 = widget.inputs["float1"]
    n2 = widget.inputs["float2"]
    out1 = widget.outputs["out1"]
    t = np.linspace(0, 10, 100)
    y = n1.value * np.sin(n2.value*t)
    out1.add_trace(
        go.Scatter(x=t, y=y,
                    mode='markers',
                    name='n1:'+str(n1.value)+", n2:"+str(n2.value))
    )

# %%
s = WidgetConstructor(schema)
s.ResetFun = ResetFun
s.ClickFun = ClickFun
s.assemble()
s
# Out:
# HTML(value="<link rel='stylesheet' href='https://fonts.googleapis.com/icon?family=Material+Icons'/><style>.p-W…
# HTML(value="<link rel='stylesheet' href='https://fonts.googleapis.com/icon?family=Material+Icons'/><style>.p-W…
# WidgetConstructor(children=(VBox(children=(UIDLaecfdacbcbfcbWidget(help='This is a textfield', value=2.0), UID…

# %%
# Out:
# WidgetConstructor(children=(VBox(children=(UIDLaecfdacbcbfcbWidget(help='This is a textfield', value=2.0), UID…
